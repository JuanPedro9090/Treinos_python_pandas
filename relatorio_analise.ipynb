# %% [markdown]
# # Relatório de Análise 1

# %% [markdown]
# # Importando a base

# %%
import pandas as pd

# %%
dados = pd.read_csv("aluguel.csv", sep=";")

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
dados["Tipo"] = dados["Tipo"].apply(lambda x: x[:])
dados
# Out:
#       Tipo                Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Qui            Copacabana        1      0       0    40  1700.0
# 1      Cas       Jardim Botânico        2      0       1   100  7000.0
# 2      Con       Barra da Tijuca        0      4       0   150  5200.0
# 3      Apa                Centro        1      0       0    15   800.0
# 4      Apa          Higienópolis        1      0       0    48   800.0
# ...    ...                   ...      ...    ...     ...   ...     ...
# 32955  Qui                Centro        0      0       0    27   800.0
# 32956  Apa           Jacarepaguá        3      1       2    78  1800.0
# 32957  Apa  São Francisco Xavier        2      1       0    48  1400.0
# 32958  Apa                Leblon        2      0       0    70  3000.0
# 32959  Con                Centro        0      0       0   250  6500.0
#
#        Condominio    IPTU
# 0           500.0    60.0
# 1             NaN     NaN
# 2          4020.0  1111.0
# ...

# %%
def tres_letras(s):
    return s[:3]

# %%
len(dados["Valor"])
# Out:
# 32960

# %% [markdown]
# # Informações Gerais sobre a base

# %%
dados.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
tipos_de_dados = pd.DataFrame(dados.dtypes, columns = ["Tipos de Dados"])

# %%
tipos_de_dados.columns.name = "Variáveis"

# %%
tipos_de_dados
# Out:
# Variáveis  Tipos de Dados
# Tipo               object
# Bairro             object
# Quartos             int64
# Vagas               int64
# Suites              int64
# Area                int64
# Valor             float64
# Condominio        float64
# IPTU              float64

# %%
print(dados.shape)
print(dados.shape[0])
print(dados.shape[1])
# Out:
# (32960, 9)
# 32960
# 9

# %%
print("A base dados apresenta {} registros (imóveis) e {} variáveis".format(dados.shape[0],dados.shape[1]))
# Out:
# A base dados apresenta 32960 registros (imóveis) e 9 variáveis

# %%
list(dados['Tipo'].drop_duplicates())
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
residencial = ['Quitinete',
 'Casa',
 'Apartamento',
 'Casa de Condomínio',
 'Casa de Vila']

# %%
residencial
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
selecao = dados['Tipo'].isin(residencial)
selecao
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955     True
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %%
dados_residencial = dados[selecao]
dados_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
list(dados_residencial['Tipo'].drop_duplicates())
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados_residencial.shape[0]
# Out:
# 22580

# %%
dados.shape[0]
# Out:
# 32960

# %%
dados_residencial.index = range(dados_residencial.shape[0])

# %%
dados_residencial
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %% [markdown]
# # Exportando a Base de Dados

# %%
dados_residencial.to_csv("aluguel_residencial.csv", sep=";")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 dados_residencial.to_csv("aluguel_residencial.csv", sep=";")
#
# NameError: name 'dados_residencial' is not defined

# %%
dados_residencial_2 = pd.read_csv("aluguel_residencial.csv", sep=";")
dados_residencial_2
# Out:
#        Unnamed: 0         Tipo                Bairro  Quartos  Vagas  Suites  \
# 0               0    Quitinete            Copacabana        1      0       0
# 1               1         Casa       Jardim Botânico        2      0       1
# 2               2  Apartamento                Centro        1      0       0
# 3               3  Apartamento          Higienópolis        1      0       0
# 4               4  Apartamento          Vista Alegre        3      1       0
# ...           ...          ...                   ...      ...    ...     ...
# 22575       22575  Apartamento                 Méier        2      0       0
# 22576       22576    Quitinete                Centro        0      0       0
# 22577       22577  Apartamento           Jacarepaguá        3      1       2
# 22578       22578  Apartamento  São Francisco Xavier        2      1       0
# 22579       22579  Apartamento                Leblon        2      0       0
#
#        Area   Valor  Condominio  IPTU
# ...

# %%
dados_residencial_2 = pd.read_csv("aluguel_residencial.csv", sep = ";")

# %%
dados_residencial_2
# Out:
#        Unnamed: 0         Tipo                Bairro  Quartos  Vagas  Suites  \
# 0               0    Quitinete            Copacabana        1      0       0
# 1               1         Casa       Jardim Botânico        2      0       1
# 2               2  Apartamento                Centro        1      0       0
# 3               3  Apartamento          Higienópolis        1      0       0
# 4               4  Apartamento          Vista Alegre        3      1       0
# ...           ...          ...                   ...      ...    ...     ...
# 22575       22575  Apartamento                 Méier        2      0       0
# 22576       22576    Quitinete                Centro        0      0       0
# 22577       22577  Apartamento           Jacarepaguá        3      1       2
# 22578       22578  Apartamento  São Francisco Xavier        2      1       0
# 22579       22579  Apartamento                Leblon        2      0       0
#
#        Area   Valor  Condominio  IPTU
# ...

# %%
dados_residencial_2.drop(columns=['Unnamed: 0'])
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
dados2 = pd.read_csv("aluguel_residencial.csv", sep=";")

# %%
dados2.drop(columns=['Unnamed: 0'])
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
# Selecione somente os imóveis classificados com tipo "Apartamento"
selecao1 = dados2["Tipo"] == "Apartamento"
n1 = dados2[selecao1].shape[0]
n1
# Out:
# 19532

# %%
# Selecione os imóveis classificados como tipo "Casa", "Casa de Condominio" e "Casa de Vila"
selecao1 = (dados2["Tipo"] == "Casa") | (dados2["Tipo"] == "Casa de Condomínio") | (dados2["Tipo"] == "Casa de Vila")
n2 = dados2[selecao1].shape[0]
n2
# Out:
# 2212

# %%
# Selecione os imoveis com area entre 60 e 100 metros quadrados, incluindo os limites
selecao1 = (dados2["Area"] >= 60) & (dados2["Area"] <= 100)
n3 = dados2[selecao1].shape[0]
n3
# Out:
# 8719

# %%
# Selecione os imoveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2000,00
selecao1 = (dados2["Quartos"] >=4) & (dados2["Valor"] < 2000)
n4 = dados2[selecao1].shape[0]
n4
# Out:
# 41

# %%
print("N° de imóveis classificados com tipo 'Apartamento' -> {}".format(n1))
print("N° imóveis classificados como tipo 'Casa', 'Casa de Condominio' e 'Casa de Vila' -> {}".format(n2))
print("N° de imoveis com area entre 60 e 100 metros quadrados, incluindo os limites -> {}".format(n3))
print("N° de imoveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2000,00 -> {}".format(n4))
# Out:
# N° de imóveis classificados com tipo 'Apartamento' -> 19532
# N° imóveis classificados como tipo 'Casa', 'Casa de Condominio' e 'Casa de Vila' -> 2212
# N° de imoveis com area entre 60 e 100 metros quadrados, incluindo os limites -> 8719
# N° de imoveis que tenham pelo menos 4 quartos e aluguel menor que R$ 2000,00 -> 41

# %% [markdown]
# # Tratamento de dados Faltantes

# %% [markdown]
# # Relatório de Análise V

# %%
import pandas as pd

# %%
dados_residencial_2
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
dados_residencial_2.isnull()
dados_residencial_2.notnull()
# Out:
#        Tipo  Bairro  Quartos  Vagas  Suites  Area  Valor  Condominio   IPTU
# 0      True    True     True   True    True  True   True        True   True
# 1      True    True     True   True    True  True   True       False  False
# 2      True    True     True   True    True  True   True        True   True
# 3      True    True     True   True    True  True   True        True  False
# 4      True    True     True   True    True  True   True       False  False
# ...     ...     ...      ...    ...     ...   ...    ...         ...    ...
# 22575  True    True     True   True    True  True   True        True   True
# 22576  True    True     True   True    True  True   True        True   True
# 22577  True    True     True   True    True  True   True        True   True
# 22578  True    True     True   True    True  True   True        True   True
# 22579  True    True     True   True    True  True   True        True  False
#
# [22580 rows x 9 columns]

# %%
dados_residencial_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22580 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22580 non-null  object
#  1   Bairro      22580 non-null  object
#  2   Quartos     22580 non-null  int64
#  3   Vagas       22580 non-null  int64
#  4   Suites      22580 non-null  int64
#  5   Area        22580 non-null  int64
#  6   Valor       22571 non-null  float64
#  7   Condominio  20765 non-null  float64
#  8   IPTU        15795 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
dados_residencial_2[dados_residencial_2["Valor"].isnull()]
# Out:
#              Tipo           Bairro  Quartos  Vagas  Suites  Area  Valor  \
# 58    Apartamento  Barra da Tijuca        2      1       1    70    NaN
# 1492  Apartamento             Leme        2      0       0    75    NaN
# 1683         Casa     Campo Grande        3      4       3   363    NaN
# 2012  Apartamento         Botafogo        2      0       0    95    NaN
# 2034  Apartamento       Copacabana        2      0       0    72    NaN
# 4941         Casa     Campo Grande        3      2       1   100    NaN
# 8568  Apartamento             Leme        2      0       1    75    NaN
# 8947  Apartamento           Glória        3      0       1   135    NaN
# 9149  Apartamento            Gávea        3      1       1   105    NaN
#
#       Condominio   IPTU
# 58         970.0   68.0
# 1492       878.0    NaN
# 1683         NaN    NaN
# 2012      1010.0  170.0
# 2034       850.0    NaN
# 4941         NaN    NaN
# 8568       878.0    NaN
# 8947       910.0  228.0
# ...

# %%
A = dados_residencial_2.shape[0]
dados_residencial_2.dropna(subset = ["Valor"],inplace = True)
B = dados_residencial_2.shape[0]
A - B
# Out:
# 9

# %%
dados_residencial_2[dados_residencial_2["Valor"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
dados_residencial_2[dados_residencial_2["Condominio"].isnull()].shape[0]
# Out:
# 1813

# %%
selecao = (dados_residencial_2["Tipo"]=='Apartamento') & (dados_residencial_2['Condominio'].isnull())

# %%
A = dados_residencial_2.shape[0]
dados_residencial_2 = dados_residencial_2[~selecao]
B = dados_residencial_2.shape[0]
A - B
# Out:
# 745

# %%
dados_residencial_2[dados_residencial_2["Condominio"].isnull()].shape[0]
# Out:
# 1068

# %%
dados3 = dados_residencial_2.fillna({'Condominio': 0, 'IPTU':0})

# %%
dados3[dados3["IPTU"].isnull()].shape[0]
dados3[dados3["Condominio"].isnull()].shape[0]
# Out:
# 0

# %%
dados3.to_csv('introducao-a-data-science-aula1/aluguel_residencial3.csv', sep=';', index = False)

# %% [markdown]
# # Adicionando novas colunas com valores

# %%
import pandas as pd

# %%
dados = pd.read_csv("aluguel_residencial.csv", sep=";")

# %%
dados.head(10)
# Out:
#    Unnamed: 0                Tipo           Bairro  Quartos  Vagas  Suites  \
# 0           0           Quitinete       Copacabana        1      0       0
# 1           1                Casa  Jardim Botânico        2      0       1
# 2           2         Apartamento           Centro        1      0       0
# 3           3         Apartamento     Higienópolis        1      0       0
# 4           4         Apartamento     Vista Alegre        3      1       0
# 5           5         Apartamento         Cachambi        2      0       0
# 6           6  Casa de Condomínio  Barra da Tijuca        5      4       5
# 7           7  Casa de Condomínio            Ramos        2      2       0
# 8           8         Apartamento           Centro        1      0       0
# 9           9         Apartamento           Grajaú        2      1       0
#
#    Area    Valor  Condominio  IPTU
# 0    40   1700.0       500.0  60.0
# 1   100   7000.0         NaN   NaN
# 2    15    800.0       390.0  20.0
# ...

# %%
dados.drop(columns=['Unnamed: 0'], inplace=True)

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
dados["Valor Bruto"] = dados["Valor"] + dados["Condominio"] + dados["IPTU"]

# %%
dados["Valor m2"] = dados["Valor"] / dados["Area"]

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU  Valor Bruto   Valor m2
# 0       500.0  60.0       2260.0  42.500000
# ...

# %%
dados["Valor m2"] = dados["Valor m2"].round(2)

# %%
dados["Valor Bruto m2"] = (dados["Valor Bruto"] / dados["Area"]).round(2)

# %%
dados.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU  Valor Bruto  Valor m2  Valor Bruto m2
# ...

# %%
casa = ['Casa', 'Casa de Condominio', 'Casa de Vila']

# %%
dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22575  Apartamento                 Méier        2      0       0    70
# 22576    Quitinete                Centro        0      0       0    27
# 22577  Apartamento           Jacarepaguá        3      1       2    78
# 22578  Apartamento  São Francisco Xavier        2      1       0    48
# 22579  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU  Valor Bruto  Valor m2  Valor Bruto m2  \
# ...

# %% [markdown]
# # Excluindo variáveis

# %%
dados_aux = pd.DataFrame(dados[['Tipo Agregado','Valor m2','Valor Bruto','Valor Bruto m2']])

# %%
dados_aux
# Out:
#       Tipo Agregado  Valor m2  Valor Bruto  Valor Bruto m2
# 0       Apartamento     42.50       2260.0           56.50
# 1              Casa     70.00          NaN             NaN
# 2       Apartamento     53.33       1210.0           80.67
# 3       Apartamento     16.67          NaN             NaN
# 4       Apartamento     17.14          NaN             NaN
# ...             ...       ...          ...             ...
# 22575   Apartamento     12.86       1438.0           20.54
# 22576   Apartamento     29.63       1175.0           43.52
# 22577   Apartamento     23.08       2640.0           33.85
# 22578   Apartamento     29.17       1946.0           40.54
# 22579   Apartamento     42.86          NaN             NaN
#
# [22580 rows x 4 columns]

# %%
del dados_aux['Valor Bruto']

# %%
dados_aux
# Out:
#       Tipo Agregado  Valor m2  Valor Bruto m2
# 0       Apartamento     42.50           56.50
# 1              Casa     70.00             NaN
# 2       Apartamento     53.33           80.67
# 3       Apartamento     16.67             NaN
# 4       Apartamento     17.14             NaN
# ...             ...       ...             ...
# 22575   Apartamento     12.86           20.54
# 22576   Apartamento     29.63           43.52
# 22577   Apartamento     23.08           33.85
# 22578   Apartamento     29.17           40.54
# 22579   Apartamento     42.86             NaN
#
# [22580 rows x 3 columns]

# %%
dados_aux.pop('Valor Bruto m2')
# Out:
# 0        56.50
# 1          NaN
# 2        80.67
# 3          NaN
# 4          NaN
#          ...
# 22575    20.54
# 22576    43.52
# 22577    33.85
# 22578    40.54
# 22579      NaN
# Name: Valor Bruto m2, Length: 22580, dtype: float64

# %%
dados_aux
# Out:
#       Tipo Agregado  Valor m2
# 0       Apartamento     42.50
# 1              Casa     70.00
# 2       Apartamento     53.33
# 3       Apartamento     16.67
# 4       Apartamento     17.14
# ...             ...       ...
# 22575   Apartamento     12.86
# 22576   Apartamento     29.63
# 22577   Apartamento     23.08
# 22578   Apartamento     29.17
# 22579   Apartamento     42.86
#
# [22580 rows x 2 columns]

# %%
dados.drop(['Valor Bruto', 'Valor Bruto m2'], axis = 1, inplace=True)

# %%
dados.head(20)
# Out:
#                   Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete               Copacabana        1      0       0    40
# 1                 Casa          Jardim Botânico        2      0       1   100
# 2          Apartamento                   Centro        1      0       0    15
# 3          Apartamento             Higienópolis        1      0       0    48
# 4          Apartamento             Vista Alegre        3      1       0    70
# 5          Apartamento                 Cachambi        2      0       0    50
# 6   Casa de Condomínio          Barra da Tijuca        5      4       5   750
# 7   Casa de Condomínio                    Ramos        2      2       0    65
# 8          Apartamento                   Centro        1      0       0    36
# 9          Apartamento                   Grajaú        2      1       0    70
# 10         Apartamento      Lins de Vasconcelos        3      1       1    90
# ...

# %%
dados.to_csv("aluguel_residencial.csv", sep=";", index=False)
